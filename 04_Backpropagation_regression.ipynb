# %% [markdown]
# ## Backpropagation in Regression

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8,8,4], [7,9,5], [6,10,6], [5,12,7]], columns = ['CGPA', 'Profile_Score', 'LPA'])

# %%
df
# Out:
#    CGPA  Profile_Score  LPA
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initialize_parameter(layer_dims):
    parameters = {}
    for i in range(1, len(layer_dims)):
        parameters['W' + str(i)] = np.ones((layer_dims[i-1], layer_dims[i])) * 0.01
        parameters['b'+ str(i)] = np.zeros((layer_dims[i], 1))

    return parameters

# %%
initialize_parameter([2,2,1])
# Out:
# {'W1': array([[0.01, 0.01],
#         [0.01, 0.01]]),
#  'b1': array([[0.],
#         [0.]]),
#  'W2': array([[0.01],
#         [0.01]]),
#  'b2': array([[0.]])}

# %%
def linear_forward(A_prev, W, b):
    Z = np.dot(W.T, A_prev) + b
    
    return Z

# %%
#Forward Propagation

def L_layer_forward(X, parameters):

    A = X
    L = len(parameters) // 2

    for l in range(1, L+1):
        A_prev = A
        Wl = parameters['W' + str(l)]
        bl = parameters['b' + str(l)]

        print("A" + str(l-1) + ":", A_prev)
        print("W" + str(l) + ":", Wl)
        print("b" + str(l) + ":", bl)
        print("____"*5)

        A = linear_forward(A_prev, Wl, bl)
        print("A"+str(l)+": ", A)
        print("**"*20)
            
    return A,A_prev

# %%
X = df[['CGPA', 'Profile_Score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['LPA']].values[0][0]

# Parameter initialization
parameters = initialize_parameter([2,2,1])

y_hat,A1 = L_layer_forward(X, parameters)
# Out:
# A0: [[8]
#  [8]]
# W1: [[0.01 0.01]
#  [0.01 0.01]]
# b1: [[0.]
#  [0.]]
# ____________________
# A1:  [[0.16]
#  [0.16]]
# ****************************************
# A1: [[0.16]
#  [0.16]]
# W2: [[0.01]
#  [0.01]]
# b2: [[0.]]
# ____________________
# A2:  [[0.0032]]
# ****************************************

# %%
df[['CGPA', 'Profile_Score']].values[0].shape
# Out:
# (2,)

# %%
y_hat = y_hat[0][0]

# %%
A1
# Out:
# array([[0.16],
#        [0.16]])

# %%
def update_parameters(parameters, y, y_hat, A1, X):
    parameters['W2'][0][0] = parameters['W2'][0][0] + (0.001 * 2 * (y - y_hat))
